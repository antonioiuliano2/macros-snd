# %% [markdown]
# # Code to draw events from csv file
#
# First we import modules: python module and my library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import dfeventdisplay

# %% [markdown]
# then we read the dataframe

# %%
df = pd.read_csv("/eos/user/a/aiulian/sim_fedra/SNDnuyield_30_September_2021/b000022/brick22.csv")

# %%
# %matplotlib inline
figxz,axisxz = plt.subplots()
figyz,axisyz = plt.subplots()
dfeventdisplay.displayevent(df,246,"b",axisyz,axisxz)

# %%
df1 = df.groupby("MCEvent").last()

# %%
df1.query("PID<59").head()
# Out:
#            ID  PID          x           y        z        TX        TY  \
# MCEvent
# 246       762   33  368953.97   42358.086 -43395.0 -1.220746  0.140612
# 440      1574   52  384338.44   30580.113 -68380.0 -0.466573  0.297924
# 598      2864   35  310431.70  190978.270 -46025.0  0.491825 -0.957046
# 619      3523   18  255019.38  170052.030 -23670.0  1.164333 -0.118879
# 813      4259    7  371141.94   84347.030  -9205.0  0.238096  0.397001
#
#          MCTrack  MCMotherID         P  Flag  FEDRATrackID
# MCEvent
# 246            3           0  0.442640  2212       20046.0
# 440           16          12  0.224915    11           NaN
# 598           10           0  0.241378  -211       28583.0
# 619          739         738  0.118399  2212       11916.0
# 813          229           2  0.225870  -211        6118.0
