// %% [markdown]
// # Inspecting GENIE cross section
//
// Input. rootracker tree, converted from GHEP file with gntpc rootracker
//
// First, select numu CCDIS interactions into tungsten

// %%
auto df = ROOT::RDataFrame("gRooTracker","/eos/experiment/sndlhc/users/aiulian/ADVSND/numu_volAdvTarget_ElectrDesign_rootracker/all_rootracker.root")
// Out:
// (ROOT::RDataFrame &) A data frame associated to the data source "TTree data source"

// %%
// Example: Extract only the Energy (index 3) for all particles
auto df2 = df.Define("NuEnergy", [](const ROOT::RVec<double>& p4) {
    return p4[3];
}, {"StdHepP4"});

auto df3 = df2.Define("xsecN_overE","EvtXSec/(NuEnergy*184)");

// %%
//filter per neutrino type
auto df_numu = df3.Filter("StdHepPdg[0]==14");
//target must be tungsten
auto df_numu_W = df_numu.Filter("StdHepPdg[1]==1000741840");
// interaction type CCDIS
auto df_numuccdis_W = df_numu_W.Filter("fString.Contains(\"CC\")&&fString.Contains(\"DIS\")");

// %%
const int nbinsE = 700;
const double minE = 0.;
const double maxE = 7000.;

const int nbinsxsec = 1000;
const double minxsec = 0.;
const double maxxsec = 1.;

// %%
auto hsigmaE = df_numuccdis_W.Histo2D({"hsigmaE","Cross Section numu CCDIS",nbinsE,minE,maxE,nbinsxsec,minxsec,1},"NuEnergy","xsecN_overE");

// %%
auto hnuE = df2.Histo1D("NuEnergy");

// %%
TCanvas * c = new TCanvas();
hnuE->Draw();
c->Draw();
// Out:
// <div id="root_plot_1778601646250" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1778601646250() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(22055,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1778601646250', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
TCanvas * c2 = new TCanvas();
hsigmaE->Draw();
c2->Draw();
// Out:
// <div id="root_plot_1778601646533" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1778601646533() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(34696,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1778601646533', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %% [markdown]
// ### Splitting for target quark
//
// There are multiple curves, they can be inspected by checking the target nucleon

// %%
auto df_neutron = df_numuccdis_W.Filter("StdHepPdg[2]==2112");
auto df_neutron_valence = df_neutron.Filter("fString.Contains(\"v\")");
auto df_neutron_sea = df_neutron.Filter("fString.Contains(\"s\")");

auto df_proton = df_numuccdis_W.Filter("StdHepPdg[2]==2212");
auto df_proton_valence = df_proton.Filter("fString.Contains(\"v\")");
auto df_proton_sea = df_proton.Filter("fString.Contains(\"s\")");

// %%
auto df_neutron_valence_up = df_neutron_valence.Filter("fString.Contains(\"q:2\")");
auto df_neutron_valence_down = df_neutron_valence.Filter("fString.Contains(\"q:1\")");

// %%
auto df_proton_valence_up = df_proton_valence.Filter("fString.Contains(\"q:2\")");
auto df_proton_valence_down = df_proton_valence.Filter("fString.Contains(\"q:1\")");

// %%
//get sub quarks from the sea
auto df_neutron_sea_up = df_neutron_sea.Filter("fString.Contains(\"q:2\")");
auto df_neutron_sea_down = df_neutron_sea.Filter("fString.Contains(\"q:1\")");
auto df_neutron_sea_strange = df_neutron_sea.Filter("fString.Contains(\"q:3\")");
auto df_neutron_sea_charm = df_neutron_sea.Filter("fString.Contains(\"q:4\")");
auto df_neutron_sea_bottom = df_neutron_sea.Filter("fString.Contains(\"q:5\")");
auto df_neutron_sea_top = df_neutron_sea.Filter("fString.Contains(\"q:6\")");

// %%
//get sub quarks from the sea proton
auto df_proton_sea_up = df_proton_sea.Filter("fString.Contains(\"q:2\")");
auto df_proton_sea_down = df_proton_sea.Filter("fString.Contains(\"q:1\")");
auto df_proton_sea_strange = df_proton_sea.Filter("fString.Contains(\"q:3\")");
auto df_proton_sea_charm = df_proton_sea.Filter("fString.Contains(\"q:4\")");
auto df_proton_sea_bottom = df_proton_sea.Filter("fString.Contains(\"q:5\")");
auto df_proton_sea_top = df_proton_sea.Filter("fString.Contains(\"q:6\")");

// %%
auto hsigmaE_nv = df_neutron_valence.Histo2D({"hsigmaE_nv","Cross Section numu CCDIS",nbinsE,minE,maxE,nbinsxsec,minxsec,maxxsec},"NuEnergy","xsecN_overE");
auto hsigmaE_ns = df_neutron_sea.Histo2D({"hsigmaE_ns","Cross Section numu CCDIS",nbinsE,minE,maxE,nbinsxsec,minxsec,maxxsec},"NuEnergy","xsecN_overE");
auto hsigmaE_pv = df_proton_valence.Histo2D({"hsigmaE_pv","Cross Section numu CCDIS",nbinsE,minE,maxE,nbinsxsec,minxsec,maxxsec},"NuEnergy","xsecN_overE");
auto hsigmaE_ps = df_proton_sea.Histo2D({"hsigmaE_ps","Cross Section numu CCDIS",nbinsE,minE,maxE,nbinsxsec,minxsec,maxxsec},"NuEnergy","xsecN_overE");

// %%
auto hsigmaE_nv_up = df_neutron_valence_up.Histo2D({"hsigmaE_nv_up","Cross Section numu CCDIS",nbinsE,minE,maxE,nbinsxsec,minxsec,1},"NuEnergy","xsecN_overE");
auto hsigmaE_nv_down = df_neutron_valence_down.Histo2D({"hsigmaE_nv_down","Cross Section numu CCDIS",nbinsE,minE,maxE,nbinsxsec,minxsec,1},"NuEnergy","xsecN_overE");

auto hsigmaE_pv_up = df_proton_valence_up.Histo2D({"hsigmaE_pv_up","Cross Section numu CCDIS",nbinsE,minE,maxE,nbinsxsec,minxsec,1},"NuEnergy","xsecN_overE");
auto hsigmaE_pv_down = df_proton_valence_down.Histo2D({"hsigmaE_pv_down","Cross Section numu CCDIS",nbinsE,minE,maxE,nbinsxsec,minxsec,1},"NuEnergy","xsecN_overE");

// %%
auto hsigmaE_ns_up = df_neutron_sea_up.Histo2D({"hsigmaE_ns_up","Cross Section numu CCDIS",nbinsE,minE,maxE,nbinsxsec,minxsec,maxxsec},"NuEnergy","xsecN_overE");
auto hsigmaE_ns_down = df_neutron_sea_down.Histo2D({"hsigmaE_ns_down","Cross Section numu CCDIS",nbinsE,minE,maxE,nbinsxsec,minxsec,maxxsec},"NuEnergy","xsecN_overE");
auto hsigmaE_ns_charm = df_neutron_sea_charm.Histo2D({"hsigmaE_ns_charm","Cross Section numu CCDIS",nbinsE,minE,maxE,nbinsxsec,minxsec,maxxsec},"NuEnergy","xsecN_overE");
auto hsigmaE_ns_strange = df_neutron_sea_strange.Histo2D({"hsigmaE_ns_strange","Cross Section numu CCDIS",nbinsE,minE,maxE,nbinsxsec,minxsec,maxxsec},"NuEnergy","xsecN_overE");
auto hsigmaE_ns_top = df_neutron_sea_top.Histo2D({"hsigmaE_ns_top","Cross Section numu CCDIS",nbinsE,minE,maxE,nbinsxsec,minxsec,maxxsec},"NuEnergy","xsecN_overE");
auto hsigmaE_ns_bottom = df_neutron_sea_bottom.Histo2D({"hsigmaE_ns_bottom","Cross Section numu CCDIS",nbinsE,minE,maxE,nbinsxsec,minxsec,maxxsec},"NuEnergy","xsecN_overE");

// %%
auto hsigmaE_ps_up = df_proton_sea_up.Histo2D({"hsigmaE_ps_up","Cross Section numu CCDIS",nbinsE,minE,maxE,nbinsxsec,minxsec,maxxsec},"NuEnergy","xsecN_overE");
auto hsigmaE_ps_down = df_proton_sea_down.Histo2D({"hsigmaE_ps_down","Cross Section numu CCDIS",nbinsE,minE,maxE,nbinsxsec,minxsec,maxxsec},"NuEnergy","xsecN_overE");
auto hsigmaE_ps_charm = df_proton_sea_charm.Histo2D({"hsigmaE_ps_charm","Cross Section numu CCDIS",nbinsE,minE,maxE,nbinsxsec,minxsec,maxxsec},"NuEnergy","xsecN_overE");
auto hsigmaE_ps_strange = df_proton_sea_strange.Histo2D({"hsigmaE_ps_strange","Cross Section numu CCDIS",nbinsE,minE,maxE,nbinsxsec,minxsec,maxxsec},"NuEnergy","xsecN_overE");
auto hsigmaE_ps_top = df_proton_sea_top.Histo2D({"hsigmaE_ps_top","Cross Section numu CCDIS",nbinsE,minE,maxE,nbinsxsec,minxsec,maxxsec},"NuEnergy","xsecN_overE");
auto hsigmaE_ps_bottom = df_proton_sea_bottom.Histo2D({"hsigmaE_ps_bottom","Cross Section numu CCDIS",nbinsE,minE,maxE,nbinsxsec,minxsec,maxxsec},"NuEnergy","xsecN_overE");

// %%
TCanvas *cp_v = new TCanvas();

cp_v->Divide(2,1);
cp_v->cd(1);
hsigmaE_pv_up->Draw();
cp_v->cd(2);
hsigmaE_pv_down->Draw();
cp_v->Draw();
// Out:
// <div id="root_plot_1778601654562" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1778601654562() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(34163,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1778601654562', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
TCanvas *cn_v = new TCanvas();

cn_v->Divide(2,1);
cn_v->cd(1);
hsigmaE_nv_up->Draw();
cn_v->cd(2);
hsigmaE_nv_down->Draw();
cn_v->Draw();
// Out:
// <div id="root_plot_1778601654799" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1778601654799() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(36755,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1778601654799', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
TCanvas *cn_s = new TCanvas();
cn_s->Divide(3,2);
cn_s->cd(1);
hsigmaE_ns_up->Draw();
cn_s->cd(2);
hsigmaE_ns_down->Draw();
cn_s->cd(3);
hsigmaE_ns_charm->Draw();
cn_s->cd(4);
hsigmaE_ns_strange->Draw();
cn_s->cd(5);
hsigmaE_ns_top->Draw();
cn_s->cd(6);
hsigmaE_ns_bottom->Draw();
cn_s->Draw();
// Out:
// <div id="root_plot_1778601655224" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1778601655224() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(65055,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1778601655224', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %%
TCanvas *cp_s = new TCanvas();
cp_s->Divide(3,2);
cp_s->cd(1);
hsigmaE_ps_up->Draw();
cp_s->cd(2);
hsigmaE_ps_down->Draw();
cp_s->cd(3);
hsigmaE_ps_charm->Draw();
cp_s->cd(4);
hsigmaE_ps_strange->Draw();
cp_s->cd(5);
hsigmaE_ps_top->Draw();
cp_s->cd(6);
hsigmaE_ps_bottom->Draw();
cp_s->Draw();
// Out:
// <div id="root_plot_1778601655668" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1778601655668() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(64871,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1778601655668', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...

// %% [markdown]
// ## Trying to sum them together

// %%
auto prof_sigmaE_pv = df_proton_valence.Profile1D({"prof_sigmaE_pv","Cross Section numu CCDIS",nbinsE,minE,maxE,minxsec,maxxsec},"NuEnergy","xsecN_overE");
auto prof_sigmaE_nv = df_neutron_valence.Profile1D({"prof_sigmaE_nv","Cross Section numu CCDIS",nbinsE,minE,maxE,minxsec,maxxsec},"NuEnergy","xsecN_overE");

auto prof_sigmaE_ps_up = df_proton_sea_up.Profile1D({"prof_sigmaE_ps_up","Cross Section numu CCDIS",nbinsE,minE,maxE,minxsec,maxxsec},"NuEnergy","xsecN_overE");
auto prof_sigmaE_ps_down = df_proton_sea_down.Profile1D({"prof_sigmaE_ps_down","Cross Section numu CCDIS",nbinsE,minE,maxE,minxsec,maxxsec},"NuEnergy","xsecN_overE");
auto prof_sigmaE_ps_charm = df_proton_sea_charm.Profile1D({"prof_sigmaE_ps_charm","Cross Section numu CCDIS",nbinsE,minE,maxE,minxsec,maxxsec},"NuEnergy","xsecN_overE");
auto prof_sigmaE_ps_strange = df_proton_sea_strange.Profile1D({"prof_sigmaE_ps_strange","Cross Section numu CCDIS",nbinsE,minE,maxE,minxsec,maxxsec},"NuEnergy","xsecN_overE");
auto prof_sigmaE_ps_top = df_proton_sea_top.Profile1D({"prof_sigmaE_ps_top","Cross Section numu CCDIS",nbinsE,minE,maxE,minxsec,maxxsec},"NuEnergy","xsecN_overE");
auto prof_sigmaE_ps_bottom = df_proton_sea_bottom.Profile1D({"prof_sigmaE_ps_down","Cross Section numu CCDIS",nbinsE,minE,maxE,minxsec,maxxsec},"NuEnergy","xsecN_overE");

auto prof_sigmaE_ns_up = df_neutron_sea_up.Profile1D({"prof_sigmaE_ns_up","Cross Section numu CCDIS",nbinsE,minE,maxE,minxsec,maxxsec},"NuEnergy","xsecN_overE");
auto prof_sigmaE_ns_down = df_neutron_sea_down.Profile1D({"prof_sigmaE_ns_down","Cross Section numu CCDIS",nbinsE,minE,maxE,minxsec,maxxsec},"NuEnergy","xsecN_overE");
auto prof_sigmaE_ns_charm = df_neutron_sea_charm.Profile1D({"prof_sigmaE_ns_charm","Cross Section numu CCDIS",nbinsE,minE,maxE,minxsec,maxxsec},"NuEnergy","xsecN_overE");
auto prof_sigmaE_ns_strange = df_neutron_sea_strange.Profile1D({"prof_sigmaE_ns_strange","Cross Section numu CCDIS",nbinsE,minE,maxE,minxsec,maxxsec},"NuEnergy","xsecN_overE");
auto prof_sigmaE_ns_top = df_neutron_sea_top.Profile1D({"prof_sigmaE_ns_top","Cross Section numu CCDIS",nbinsE,minE,maxE,minxsec,maxxsec},"NuEnergy","xsecN_overE");
auto prof_sigmaE_ns_bottom = df_neutron_sea_bottom.Profile1D({"prof_sigmaE_ns_down","Cross Section numu CCDIS",nbinsE,minE,maxE,minxsec,maxxsec},"NuEnergy","xsecN_overE");

// %%
TCanvas *ctot = new TCanvas();
// 1. Ottieni gli oggetti TH1D dai profili
// ProjectionX() crea un nuovo istogramma con i valori medi del profilo
TH1D* h1 = prof_sigmaE_pv->ProjectionX("h1");
TH1D* h2 = prof_sigmaE_nv->ProjectionX("h2");

TH1D* h3 = prof_sigmaE_ps_up->ProjectionX("h3");
TH1D* h4 = prof_sigmaE_ps_down->ProjectionX("h4");
TH1D* h5 = prof_sigmaE_ps_charm->ProjectionX("h5");
TH1D* h6 = prof_sigmaE_ps_strange->ProjectionX("h6");
TH1D* h7 = prof_sigmaE_ps_top->ProjectionX("h7");
TH1D* h8 = prof_sigmaE_ps_bottom->ProjectionX("h8");

TH1D* h9 = prof_sigmaE_ns_up->ProjectionX("h9");
TH1D* h10 = prof_sigmaE_ns_down->ProjectionX("h10");
TH1D* h11 = prof_sigmaE_ns_charm->ProjectionX("h11");
TH1D* h12 = prof_sigmaE_ns_strange->ProjectionX("h12");
TH1D* h13 = prof_sigmaE_ns_top->ProjectionX("h13");
TH1D* h14 = prof_sigmaE_ns_bottom->ProjectionX("h14");

// 2. Crea l'istogramma somma
TH1D* h_sum = (TH1D*)h1->Clone("h_sum");
h_sum->SetTitle("Somma non pesata (y1 + y2)");
// 3. Esegui la somma aritmetica
h_sum->Add(h2); h_sum->Add(h3); h_sum->Add(h4); h_sum->Add(h5); h_sum->Add(h6); h_sum->Add(h7);
h_sum->Add(h8); h_sum->Add(h9); h_sum->Add(h10); h_sum->Add(h11); h_sum->Add(h12); h_sum->Add(h13);
h_sum->Add(h14);

h_sum->Draw();
ctot->Draw();
// Out:
// <div id="root_plot_1778601660834" style="width: 700px; height: 500px; position: relative">
// </div>
// <script>
//    function process_root_plot_1778601660834() {
//       function drawPlot(Core) {
//          Core.settings.HandleKeys = false;
//          Core.unzipJSON(33153,'...').then(json => {
//             const obj = Core.parse(json);
//             Core.draw('root_plot_1778601660834', obj, '');
//          });
//       }
//       const servers = ['/static/', 'https://root.cern/js/7.10.0/', 'https://jsroot.gsi.de/7.10.0/'],
//             path = 'build/jsroot';
//       if (typeof JSROOT !== 'undefined')
//          drawPlot(JSROOT);
//       else if (typeof requirejs !== 'undefined') {
//          servers.forEach((s,i) => { servers[i] = s + path; });
//          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  drawPlot);
//       } else {
//          const config = document.getElementById('jupyter-config-data');
//          if (config)
// ...
